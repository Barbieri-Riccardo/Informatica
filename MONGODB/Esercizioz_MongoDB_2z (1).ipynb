# %%
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb://webUser:xxx123xxx@cluster0-shard-00-00.algwo.mongodb.net:27017,cluster0-shard-00-01.algwo.mongodb.net:27017,cluster0-shard-00-02.algwo.mongodb.net:27017/?ssl=true&replicaSet=atlas-am4cb3-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
db = client.sample_mflix #nome del database
db

# %%
cop = db.movies.find()
copiaz = pd.DataFrame(list(cop))
copiaz.head()
# Out:
#                         _id  \
# 0  573a1391f29313caabcd68d0
# 1  573a1391f29313caabcd6ea2
# 2  573a1391f29313caabcd6d90
# 3  573a1390f29313caabcd4eaf
# 4  573a1390f29313caabcd5ea4
#
#                                                 plot                   genres  \
# 0  A penniless young man tries to save an heiress...  [Comedy, Short, Action]
# 1  The simple-minded son of a rich financier must...                 [Comedy]
# 2  As Alice and Cora Munro attempt to find their ...       [Adventure, Drama]
# 3  A woman, with the aid of her police officer sw...           [Crime, Drama]
# 4  A District Attorney's outspoken stand on abort...                  [Drama]
#
#    runtime      rated                                               cast  \
# 0     22.0       TV-G  [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...
# 1     77.0        NaN  [Edward Jobson, Beulah Booker, Edward Connelly...
# 2     73.0  NOT RATED  [Wallace Beery, Barbara Bedford, Alan Roscoe, ...
# 3     88.0      TV-PG  [Jane Gail, Ethel Grandin, William H. Turner, ...
# 4     62.0   APPROVED  [Tyrone Power Sr., Helen Riaume, Marie Walcamp...
#
#                                               poster  \
# 0  https://m.media-amazon.com/images/M/MV5BNzE1OW...
# 1  https://m.media-amazon.com/images/M/MV5BZDNiOD...
# 2  https://m.media-amazon.com/images/M/MV5BZmJkZD...
# 3  https://m.media-amazon.com/images/M/MV5BYzk0YW...
# 4                                                NaN
#
#                       title  \
# 0        From Hand to Mouth
# 1               The Saphead
# 2  The Last of the Mohicans
# 3          Traffic in Souls
# 4    Where Are My Children?
#
#                                             fullplot  languages  ...  \
# 0  As a penniless man worries about how he will m...  [English]  ...
# 1  Nick Van Alstyne owns the Henrietta silver min...        NaN  ...
# 2  As Alice and Cora Munro attempt to find their ...  [English]  ...
# 3                                                NaN  [English]  ...
# 4  While prosecuting a physician for the death of...  [English]  ...
#
#                                              writers  \
# 0                             [H.M. Walker (titles)]
# 1  [Bronson Howard (original play "The Henrietta"...
# 2  [James Fenimore Cooper (novel), Robert Dillon ...
# 3                                                NaN
# 4  [Lucy Payton (from the story by), Franklin Hal...
#
#                                               awards  \
# 0  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 1  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 2    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 3    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 4    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
#
#                      lastupdated  year  \
# 0  2015-04-17 00:16:14.220000000  1919
# 1  2015-06-20 00:38:08.303000000  1920
# 2  2015-07-19 00:12:27.010000000  1920
# 3  2015-09-15 02:07:14.247000000  1913
# 4  2015-09-07 00:51:32.560000000  1916
#
#                                           imdb countries   type  \
# 0   {'rating': 7.0, 'votes': 639, 'id': 10146}     [USA]  movie
# 1  {'rating': 6.2, 'votes': 1020, 'id': 11652}     [USA]  movie
# 2   {'rating': 6.9, 'votes': 773, 'id': 11387}     [USA]  movie
# 3    {'rating': 6.0, 'votes': 371, 'id': 3471}     [USA]  movie
# 4    {'rating': 5.9, 'votes': 247, 'id': 7558}     [USA]  movie
#
#                                             tomatoes num_mflix_comments  \
# 0  {'viewer': {'rating': 3.3, 'numReviews': 71, '...                NaN
# 1  {'viewer': {'rating': 3.3, 'numReviews': 435, ...                2.0
# 2  {'viewer': {'rating': 3.5, 'numReviews': 306, ...                NaN
# 3  {'viewer': {'rating': 3.0, 'numReviews': 85, '...                2.0
# 4  {'viewer': {'rating': 3.1, 'numReviews': 34, '...                NaN
#
#   metacritic
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# 1. Gli attori dei film

# %%
result = db.movies.aggregate([
                               {"$unwind":"$cast"},
                               {"$group":{"_id":"$cast"}}
                                      ])
df = pd.DataFrame(list(result))
df
# Out:
#                     _id
# 0           Matt Newton
# 1        Janne Virtanen
# 2      Joolia Cappleman
# 3        Cissy Meddings
# 4           June Duprez
# ...                 ...
# 42145        Wenders Li
# 42146  Damaine Radcliff
# 42147      Babett Jèvor
# 42148   Viviana Herrera
# 42149       Conrad Bain
#
# [42150 rows x 1 columns]

# %% [markdown]
# 2. Gli attori il cui nome comincia per A

# %%
result=db.movies.aggregate([
                            {"$unwind": "$cast"},
                            { "$match" :{"cast":{"$regex":"^A.*"}}}
])
df=pd.DataFrame(list(result))
df
# Out:
#                            _id  \
# 0     573a1391f29313caabcd6d90
# 1     573a1390f29313caabcd5b9a
# 2     573a1391f29313caabcd7616
# 3     573a1391f29313caabcd9600
# 4     573a1391f29313caabcd7ac4
# ...                        ...
# 7465  573a13faf29313caabdec74f
# 7466  573a13faf29313caabdec74f
# 7467  573a13f8f29313caabde8d7a
# 7468  573a13f7f29313caabde67ea
# 7469  573a13f8f29313caabde8161
#
#                                                    plot  \
# 0     As Alice and Cora Munro attempt to find their ...
# 1     In the wayward western town known as Hell's Hi...
# 2     Salome, the daughter of Herodias, seduces her ...
# 3     With the aid of a wealthy erratic tippler, a d...
# 4     A fire engulfs a shipload of prospectors and a...
# ...                                                 ...
# 7465                                                NaN
# 7466                                                NaN
# 7467  Costi leads a peaceful life. At night he likes...
# 7468  After the loss of both parents, 11 years old O...
# 7469                                                NaN
#
#                            genres  runtime      rated                  cast  \
# 0              [Adventure, Drama]     73.0  NOT RATED           Alan Roscoe
# 1              [Romance, Western]     64.0    UNRATED  Alfred Hollingsworth
# 2     [Biography, Drama, History]     72.0        NaN         Alla Nazimova
# 3        [Comedy, Drama, Romance]     87.0     PASSED      Al Ernest Garcia
# 4              [Adventure, Drama]     87.0    UNRATED    Albert Van Antwerp
# ...                           ...      ...        ...                   ...
# 7465                      [Drama]    104.0        NaN        Astrit Kabashi
# 7466                      [Drama]    104.0        NaN       Adriana Matoshi
# 7467                     [Comedy]     89.0        NaN     Adrian Purcarescu
# 7468                      [Drama]     80.0        NaN        Arthur Navarat
# 7469                          NaN    120.0        NaN        Aharon Traitel
#
#                                                  poster  \
# 0     https://m.media-amazon.com/images/M/MV5BZmJkZD...
# 1                                                   NaN
# 2     https://m.media-amazon.com/images/M/MV5BMjA0MT...
# 3     https://m.media-amazon.com/images/M/MV5BY2I4Mm...
# 4                                                   NaN
# ...                                                 ...
# 7465                                                NaN
# 7466                                                NaN
# 7467  https://m.media-amazon.com/images/M/MV5BMTUzNj...
# 7468  https://m.media-amazon.com/images/M/MV5BMjI1Mj...
# 7469                                                NaN
#
#                                     title  \
# 0                The Last of the Mohicans
# 1                           Hell's Hinges
# 2                                  Salomè
# 3                             City Lights
# 4                          The Chechahcos
# ...                                   ...
# 7465                                Babai
# 7466                                Babai
# 7467                         The Treasure
# 7468  How to Win at Checkers (Every Time)
# 7469                               Tikkun
#
#                                                fullplot          languages  \
# 0     As Alice and Cora Munro attempt to find their ...          [English]
# 1     When Reverend Robert Henley and his sister Fai...          [English]
# 2     Salome, the daughter of Herodias, seduces her ...                NaN
# 3     A tramp falls in love with a beautiful blind g...          [English]
# 4     A fire engulfs a shipload of prospectors and a...                NaN
# ...                                                 ...                ...
# 7465                                                NaN         [Albanian]
# 7466                                                NaN         [Albanian]
# 7467  Costi leads a peaceful life. At night he likes...         [Romanian]
# 7468  After the loss of both parents, 11 years old O...    [Thai, English]
# 7469                                                NaN  [Hebrew, Yiddish]
#
#       ...                                            writers  \
# 0     ...  [James Fenimore Cooper (novel), Robert Dillon ...
# 1     ...  [C. Gardner Sullivan (screenplay), C. Gardner ...
# 2     ...   [Oscar Wilde (play), Natacha Rambova (scenario)]
# 3     ...                                  [Charles Chaplin]
# 4     ...                          [Lewis H. Moomaw (story)]
# ...   ...                                                ...
# 7465  ...                                     [Visar Morina]
# 7466  ...                                     [Visar Morina]
# 7467  ...                               [Corneliu Porumboiu]
# 7468  ...  [Josh Kim (screenplay), Rattawut Lapcharoensap...
# 7469  ...                                                NaN
#
#                                                  awards  \
# 0       {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 1       {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 2       {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 3      {'wins': 3, 'nominations': 0, 'text': '3 wins.'}
# 4       {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# ...                                                 ...
# 7465  {'wins': 6, 'nominations': 1, 'text': '6 wins ...
# 7466  {'wins': 6, 'nominations': 1, 'text': '6 wins ...
# 7467  {'wins': 2, 'nominations': 2, 'text': '2 wins ...
# 7468  {'wins': 3, 'nominations': 3, 'text': '3 wins ...
# 7469  {'wins': 7, 'nominations': 1, 'text': '7 wins ...
#
#                         lastupdated  year  \
# 0     2015-07-19 00:12:27.010000000  1920
# 1     2015-08-16 01:13:00.090000000  1916
# 2     2015-04-26 00:03:19.913000000  1922
# 3     2015-09-06 00:10:05.493000000  1931
# 4     2015-08-25 00:59:36.103000000  1923
# ...                             ...   ...
# 7465  2015-08-26 00:23:12.820000000  2015
# 7466  2015-08-26 00:23:12.820000000  2015
# 7467  2015-08-29 00:01:41.687000000  2015
# 7468  2015-08-28 00:12:09.377000000  2015
# 7469  2015-09-04 00:39:57.163000000  2015
#
#                                               imdb  \
# 0       {'rating': 6.9, 'votes': 773, 'id': 11387}
# 1        {'rating': 6.4, 'votes': 531, 'id': 6780}
# 2       {'rating': 6.6, 'votes': 466, 'id': 13571}
# 3     {'rating': 8.6, 'votes': 93912, 'id': 21749}
# 4       {'rating': 6.6, 'votes': 167, 'id': 14770}
# ...                                            ...
# 7465   {'rating': 7.0, 'votes': 23, 'id': 4741170}
# 7466   {'rating': 7.0, 'votes': 23, 'id': 4741170}
# 7467  {'rating': 7.5, 'votes': 217, 'id': 4515684}
# 7468  {'rating': 7.6, 'votes': 112, 'id': 4370256}
# 7469   {'rating': 7.0, 'votes': 23, 'id': 4482858}
#
#                                              countries   type  \
# 0                                                [USA]  movie
# 1                                                [USA]  movie
# 2                                                [USA]  movie
# 3                                                [USA]  movie
# 4                                                [USA]  movie
# ...                                                ...    ...
# 7465  [Germany, Kosovo, Republic of Macedonia, France]  movie
# 7466  [Germany, Kosovo, Republic of Macedonia, France]  movie
# 7467                                 [Romania, France]  movie
# 7468                        [Thailand, USA, Indonesia]  movie
# 7469                                          [Israel]  movie
#
#                                                tomatoes num_mflix_comments  \
# 0     {'viewer': {'rating': 3.5, 'numReviews': 306, ...                NaN
# 1     {'viewer': {'rating': 3.2, 'numReviews': 98, '...                2.0
# 2     {'viewer': {'rating': 3.9, 'numReviews': 310, ...                2.0
# 3     {'viewer': {'rating': 4.4, 'numReviews': 26133...                NaN
# 4     {'viewer': {'rating': 3.4, 'numReviews': 49, '...                2.0
# ...                                                 ...                ...
# 7465                                                NaN                2.0
# 7466                                                NaN                2.0
# 7467                                                NaN                1.0
# 7468                                                NaN                NaN
# 7469                                                NaN                NaN
#
#      metacritic
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 7465        NaN
# 7466        NaN
# 7467        NaN
# 7468        NaN
# 7469        NaN
#
# [7470 rows x 22 columns]

# %% [markdown]
# 3. Gli attori che hanno recitato in film americani

# %%
result=db.movies.aggregate([{"$unwind": "$cast"},
                            {"$match" :{"countries":"USA"}},
                            {"$project":{"cast": 1, "_id":0}}
                          ])
df=pd.DataFrame(list(result))
df
# Out:
#                          cast
# 0                Harold Lloyd
# 1               Mildred Davis
# 2              'Snub' Pollard
# 3            Peggy Cartwright
# 4               Edward Jobson
# ...                       ...
# 45926    Sarah Ellen Stephens
# 45927            Toni Rakkaen
# 45928  Ingkarat Damrongsakkul
# 45929          Thira Chutikul
# 45930          Arthur Navarat
#
# [45931 rows x 1 columns]

# %% [markdown]
# 4. Gli attori che hanno recitato in film italiani e francesi

# %%
result = db.movies.aggregate([{"$unwind":"$cast"},
                              {"$match":{'$or':[{'countries':"Italy"},{'countries':"France"}]}},
                              {"$project":{"_id":0,"cast":1}}])
df2 = pd.DataFrame(list(result))
df2
# Out:
#                      cast
# 0          Albert Prèjean
# 1             Pola Illèry
# 2      Edmond T. Grèville
# 3             Bill Bocket
# 4       Alexander Granach
# ...                   ...
# 15107        Richa Chadda
# 15108       Sanjay Mishra
# 15109       Vicky Kaushal
# 15110         Vinit Kumar
# 15111     Chantal Akerman
#
# [15112 rows x 1 columns]

# %% [markdown]
# 5. I film in cui hanno recitato Margaret Singer e Sarah Ellen Stephens

# %%
result = db.movies.aggregate([{"$match": {"cast" : ["Margaret Singer","Sarah Ellen Stephens"]}}])
df2 = pd.DataFrame(list(result))
df2
# Out:
#                         _id countries                   genres  runtime  \
# 0  573a13f8f29313caabde9156     [USA]  [Short, Drama, Romance]       14
#
#                                       cast    title  \
# 0  [Margaret Singer, Sarah Ellen Stephens]  Hallway
#
#                      lastupdated  languages   released     directors  \
# 0  2015-05-21 21:15:39.987000000  [English] 2015-03-14  [Leah Shore]
#
#         writers                                             awards  year  \
# 0  [Leah Shore]  {'wins': 0, 'nominations': 1, 'text': '1 nomin...  2015
#
#                                          imdb   type
# 0  {'rating': '', 'votes': '', 'id': 4522158}  movie

# %% [markdown]
# 6. I film che non hanno la valutazione di metacritic

# %% [markdown]
# 7. Il numero di film per ogni attore. Ordinare in ordine decrescente a
# partire dall’attore che ha recitato di più

# %%
result=db.movies.aggregate([{"$unwind": "$cast"},
                            {"$group": {"_id" : "$cast", "total" : {"$sum" : 1}}},
                            {"$sort": { "total": -1 }}
                          ])
df=pd.DataFrame(list(result))
df
# Out:
#                         _id  total
# 0          Gèrard Depardieu     68
# 1            Robert De Niro     60
# 2             Michael Caine     52
# 3      Marcello Mastroianni     50
# 4             Max von Sydow     49
# ...                     ...    ...
# 42145              Lovi Poe      1
# 42146           Betsy Baker      1
# 42147           Larry Berry      1
# 42148           Lise Biskup      1
# 42149         Yuk Long Wong      1
#
# [42150 rows x 2 columns]

# %% [markdown]
# 8. I primi 10 attori della lista precedente

# %%
result=db.movies.aggregate([{"$unwind": "$cast"},
                            {"$group": {"_id" : "$cast", "total" : {"$sum" : 1}}},
                            {"$sort": { "total": -1 }},
                            {"$limit": 10}
                          ])
df=pd.DataFrame(list(result))
df
# Out:
#                     _id  total
# 0      Gèrard Depardieu     68
# 1        Robert De Niro     60
# 2         Michael Caine     52
# 3  Marcello Mastroianni     50
# 4         Max von Sydow     49
# 5          Bruce Willis     49
# 6     Samuel L. Jackson     48
# 7        Morgan Freeman     48
# 8   Christopher Plummer     47
# 9          Gene Hackman     46

# %% [markdown]
# 9. Gli attori che hanno recitato in un numero di film compreso tra 1° e 20

# %%
result=db.movies.aggregate([{"$unwind": "$cast"},
                            {"$group": {"_id" : "$cast", "total" : {"$sum" : 1}}},
                            {"$match": {'$and': [{"gt":{"total":0}},{"lt":{"total":21}}]}}
                          ])
df=pd.DataFrame(list(result))
df

# %% [markdown]
# 10. Il numero medio di film in cui ha recitato un attore

# %% [markdown]
# 11. I film che hanno un a valutazione di metacritic superiore alla media

# %% [markdown]
# 12. Il film con più attori
